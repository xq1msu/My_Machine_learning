# %% [markdown]
# This notebook is used to make a Logistic Regression instance.
#
# First of all, import all the necessary modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Parameters

# %%
num_features = 784

learning_rate = 0.1
num_epochs = 400
batch_size = 2000

# %% [markdown]
# ### Step 1: Preparing Data
#
# Here is a MNIST dataset download from
#
# https://www.kaggle.com/competitions/digit-recognizer/data?select=train.csv

# %%
df = pd.read_csv("mnist.csv")
 
df = df[(df["label"] == 1) | (df["label"] == 0)]
    
df.shape
# Out:
# (8816, 785)

# %% [markdown]
# ### Step 2 : Seperate Data to X and y

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop("label", axis=1), df["label"], test_size=0.25)

# %% [markdown]
# ### Step 3 : convert [0,255] to [0,1]

# %%
X_train, X_test = np.array(X_train, np.float32), np.array(X_test, np.float32)
y_train, y_test = np.array(y_train, np.float32), np.array(y_test, np.float32)

# %% [markdown]
# ### Step 4 : Suffling Data and batch then by using tensorflow

# %%
def load_array(data_arrays, batch_size):
    return tf.data.Dataset.from_tensor_slices(data_arrays).shuffle(buffer_size=1000).batch(batch_size)

data_iter = load_array((X_train, y_train), batch_size)

# %% [markdown]
# ### Step 5 : Defining the module and Loss function

# %%
# setting the module and Activation function

def sigmoid_module(X, w, b):  #@save
    """线性回归模型"""
    return tf.nn.sigmoid(tf.matmul(X, w) + b)

w = tf.Variable(tf.zeros([num_features,1]))
b = tf.Variable(tf.zeros(1))

# Setting Loss function
loss = tf.keras.losses.BinaryCrossentropy()

# %% [markdown]
# ### Step 6 : Defining the Optimizer

# %%
def sgd(params, grads, lr, batch_size):  #@save
    """小批量随机梯度下降"""
    for param, grad in zip(params, grads):
        param.assign_sub(lr*grad/batch_size)

# %% [markdown]
# ### Step 6 : Defining The M and Loss function

# %%
for epoch in range(num_epochs):
    # number of times we will trains this 
    for X, y in data_iter:
        # each batch
        with tf.GradientTape() as tape:
            y_pred = sigmoid_module(X, w, b)
            l = loss(y_pred, y)            
        dw, db = tape.gradient(l, [w, b])
        sgd([w, b], [dw, db], learning_rate, batch_size)
    l = loss(sigmoid_module(X_train, w, b), y_train)
    print(f'epoch {epoch + 1}, loss {l:f}')
# Out:
# epoch 1, loss 7.670411
# epoch 2, loss 7.668716
# epoch 3, loss 7.667484
# epoch 4, loss 7.667148
# epoch 5, loss 7.666644
# epoch 6, loss 7.666422
# epoch 7, loss 7.666276
# epoch 8, loss 7.666114
# epoch 9, loss 7.666080
# epoch 10, loss 7.666067
# epoch 11, loss 7.666062
# epoch 12, loss 7.666053
# epoch 13, loss 7.666042
# epoch 14, loss 7.666025
# epoch 15, loss 7.666000
# epoch 16, loss 7.665970
# epoch 17, loss 7.665913
# epoch 18, loss 7.665837
# epoch 19, loss 7.665744
# epoch 20, loss 7.665665
# epoch 21, loss 7.665704
# epoch 22, loss 7.665602
# epoch 23, loss 7.665580
# epoch 24, loss 7.665284
# epoch 25, loss 7.664994
# epoch 26, loss 7.664987
# epoch 27, loss 7.664961
# epoch 28, loss 7.664938
# epoch 29, loss 7.664911
# epoch 30, loss 7.664999
# epoch 31, loss 7.664937
# epoch 32, loss 7.664876
# epoch 33, loss 7.664692
# epoch 34, loss 7.664554
# epoch 35, loss 7.664512
# epoch 36, loss 7.664443
# epoch 37, loss 7.664429
# epoch 38, loss 7.664411
# epoch 39, loss 7.664360
# epoch 40, loss 7.664359
# epoch 41, loss 7.664454
# epoch 42, loss 7.664406
# epoch 43, loss 7.664366
# epoch 44, loss 7.664297
# epoch 45, loss 7.664352
# epoch 46, loss 7.664285
# epoch 47, loss 7.664163
# epoch 48, loss 7.664118
# epoch 49, loss 7.664092
# epoch 50, loss 7.664040
# epoch 51, loss 7.664019
# epoch 52, loss 7.664026
# epoch 53, loss 7.664026
# epoch 54, loss 7.664012
# epoch 55, loss 7.664021
# epoch 56, loss 7.664022
# epoch 57, loss 7.664001
# epoch 58, loss 7.663979
# epoch 59, loss 7.663973
# epoch 60, loss 7.663947
# epoch 61, loss 7.663929
# epoch 62, loss 7.663884
# epoch 63, loss 7.663899
# epoch 64, loss 7.663887
# epoch 65, loss 7.663888
# epoch 66, loss 7.663867
# epoch 67, loss 7.663851
# epoch 68, loss 7.663857
# epoch 69, loss 7.663836
# epoch 70, loss 7.663820
# epoch 71, loss 7.663825
# epoch 72, loss 7.663812
# epoch 73, loss 7.663799
# epoch 74, loss 7.663796
# epoch 75, loss 7.663788
# epoch 76, loss 7.663785
# epoch 77, loss 7.663793
# epoch 78, loss 7.663787
# epoch 79, loss 7.663783
# epoch 80, loss 7.663782
# epoch 81, loss 7.663786
# epoch 82, loss 7.663788
# epoch 83, loss 7.663786
# epoch 84, loss 7.663774
# epoch 85, loss 7.663773
# epoch 86, loss 7.663773
# epoch 87, loss 7.663772
# epoch 88, loss 7.663771
# epoch 89, loss 7.663775
# epoch 90, loss 7.663774
# epoch 91, loss 7.663774
# epoch 92, loss 7.663773
# epoch 93, loss 7.663772
# epoch 94, loss 7.663773
# epoch 95, loss 7.663774
# epoch 96, loss 7.663774
# epoch 97, loss 7.663773
# epoch 98, loss 7.663773
# epoch 99, loss 7.663772
# epoch 100, loss 7.663772
# epoch 101, loss 7.663771
# epoch 102, loss 7.663771
# epoch 103, loss 7.663772
# epoch 104, loss 7.663772
# epoch 105, loss 7.663771
# epoch 106, loss 7.663771
# epoch 107, loss 7.663770
# epoch 108, loss 7.663769
# epoch 109, loss 7.663769
# epoch 110, loss 7.663769
# epoch 111, loss 7.663768
# epoch 112, loss 7.663768
# epoch 113, loss 7.663768
# epoch 114, loss 7.663767
# epoch 115, loss 7.663767
# epoch 116, loss 7.663768
# epoch 117, loss 7.663767
# epoch 118, loss 7.663766
# epoch 119, loss 7.663767
# epoch 120, loss 7.663766
# epoch 121, loss 7.663765
# epoch 122, loss 7.663765
# epoch 123, loss 7.663764
# epoch 124, loss 7.663764
# epoch 125, loss 7.663762
# epoch 126, loss 7.663761
# epoch 127, loss 7.663760
# epoch 128, loss 7.663759
# epoch 129, loss 7.663758
# epoch 130, loss 7.663755
# epoch 131, loss 7.663753
# epoch 132, loss 7.663751
# epoch 133, loss 7.663745
# epoch 134, loss 7.663739
# epoch 135, loss 7.663728
# epoch 136, loss 7.663714
# epoch 137, loss 7.663696
# epoch 138, loss 7.663677
# epoch 139, loss 7.663663
# epoch 140, loss 7.663652
# epoch 141, loss 7.663648
# epoch 142, loss 7.663645
# epoch 143, loss 7.663642
# epoch 144, loss 7.663641
# epoch 145, loss 7.663639
# epoch 146, loss 7.663637
# epoch 147, loss 7.663637
# epoch 148, loss 7.663635
# epoch 149, loss 7.663635
# epoch 150, loss 7.663634
# epoch 151, loss 7.663635
# epoch 152, loss 7.663635
# epoch 153, loss 7.663634
# epoch 154, loss 7.663634
# epoch 155, loss 7.663634
# epoch 156, loss 7.663634
# epoch 157, loss 7.663634
# epoch 158, loss 7.663634
# epoch 159, loss 7.663634
# epoch 160, loss 7.663634
# epoch 161, loss 7.663634
# epoch 162, loss 7.663634
# epoch 163, loss 7.663634
# epoch 164, loss 7.663634
# epoch 165, loss 7.663634
# epoch 166, loss 7.663633
# epoch 167, loss 7.663632
# epoch 168, loss 7.663634
# epoch 169, loss 7.663632
# epoch 170, loss 7.663633
# epoch 171, loss 7.663633
# epoch 172, loss 7.663633
# epoch 173, loss 7.663632
# epoch 174, loss 7.663634
# epoch 175, loss 7.663634
# epoch 176, loss 7.663634
# epoch 177, loss 7.663634
# epoch 178, loss 7.663632
# epoch 179, loss 7.663634
# epoch 180, loss 7.663634
# epoch 181, loss 7.663632
# epoch 182, loss 7.663633
# epoch 183, loss 7.663633
# epoch 184, loss 7.663633
# epoch 185, loss 7.663633
# epoch 186, loss 7.663633
# epoch 187, loss 7.663633
# epoch 188, loss 7.663632
# epoch 189, loss 7.663632
# epoch 190, loss 7.663633
# epoch 191, loss 7.663634
# epoch 192, loss 7.663633
# epoch 193, loss 7.663633
# epoch 194, loss 7.663633
# epoch 195, loss 7.663633
# epoch 196, loss 7.663634
# epoch 197, loss 7.663634
# epoch 198, loss 7.663634
# epoch 199, loss 7.663634
# epoch 200, loss 7.663634
# epoch 201, loss 7.663634
# epoch 202, loss 7.663634
# epoch 203, loss 7.663634
# epoch 204, loss 7.663634
# epoch 205, loss 7.663634
# epoch 206, loss 7.663634
# epoch 207, loss 7.663634
# epoch 208, loss 7.663634
# epoch 209, loss 7.663634
# epoch 210, loss 7.663633
# epoch 211, loss 7.663632
# epoch 212, loss 7.663634
# epoch 213, loss 7.663634
# epoch 214, loss 7.663634
# epoch 215, loss 7.663634
# epoch 216, loss 7.663634
# epoch 217, loss 7.663634
# epoch 218, loss 7.663633
# epoch 219, loss 7.663634
# epoch 220, loss 7.663634
# epoch 221, loss 7.663634
# epoch 222, loss 7.663634
# epoch 223, loss 7.663633
# epoch 224, loss 7.663633
# epoch 225, loss 7.663632
# epoch 226, loss 7.663632
# epoch 227, loss 7.663633
# epoch 228, loss 7.663633
# epoch 229, loss 7.663634
# epoch 230, loss 7.663634
# epoch 231, loss 7.663634
# epoch 232, loss 7.663634
# epoch 233, loss 7.663633
# epoch 234, loss 7.663634
# epoch 235, loss 7.663633
# epoch 236, loss 7.663633
# epoch 237, loss 7.663633
# epoch 238, loss 7.663632
# epoch 239, loss 7.663632
# epoch 240, loss 7.663633
# epoch 241, loss 7.663632
# epoch 242, loss 7.663632
# epoch 243, loss 7.663632
# epoch 244, loss 7.663632
# epoch 245, loss 7.663632
# epoch 246, loss 7.663632
# epoch 247, loss 7.663632
# epoch 248, loss 7.663632
# epoch 249, loss 7.663632
# epoch 250, loss 7.663632
# epoch 251, loss 7.663632
# epoch 252, loss 7.663632
# epoch 253, loss 7.663632
# epoch 254, loss 7.663632
# epoch 255, loss 7.663632
# epoch 256, loss 7.663633
# epoch 257, loss 7.663633
# epoch 258, loss 7.663632
# epoch 259, loss 7.663632
# epoch 260, loss 7.663632
# epoch 261, loss 7.663632
# epoch 262, loss 7.663632
# epoch 263, loss 7.663632
# epoch 264, loss 7.663632
# epoch 265, loss 7.663632
# epoch 266, loss 7.663632
# epoch 267, loss 7.663632
# epoch 268, loss 7.663632
# epoch 269, loss 7.663632
# epoch 270, loss 7.663633
# epoch 271, loss 7.663632
# epoch 272, loss 7.663632
# epoch 273, loss 7.663632
# epoch 274, loss 7.663632
# epoch 275, loss 7.663632
# epoch 276, loss 7.663632
# epoch 277, loss 7.663632
# epoch 278, loss 7.663632
# epoch 279, loss 7.663632
# epoch 280, loss 7.663632
# epoch 281, loss 7.663632
# epoch 282, loss 7.663632
# epoch 283, loss 7.663632
# epoch 284, loss 7.663632
# epoch 285, loss 7.663632
# epoch 286, loss 7.663632
# epoch 287, loss 7.663632
# epoch 288, loss 7.663632
# epoch 289, loss 7.663632
# epoch 290, loss 7.663632
# epoch 291, loss 7.663632
# epoch 292, loss 7.663632
# epoch 293, loss 7.663632
# epoch 294, loss 7.663632
# epoch 295, loss 7.663632
# epoch 296, loss 7.663632
# epoch 297, loss 7.663632
# epoch 298, loss 7.663632
# epoch 299, loss 7.663632
# epoch 300, loss 7.663632
# epoch 301, loss 7.663632
# epoch 302, loss 7.663632
# epoch 303, loss 7.663632
# epoch 304, loss 7.663632
# epoch 305, loss 7.663632
# epoch 306, loss 7.663632
# epoch 307, loss 7.663632
# epoch 308, loss 7.663632
# epoch 309, loss 7.663632
# epoch 310, loss 7.663632
# epoch 311, loss 7.663632
# epoch 312, loss 7.663632
# epoch 313, loss 7.663632
# epoch 314, loss 7.663632
# epoch 315, loss 7.663632
# epoch 316, loss 7.663632
# epoch 317, loss 7.663632
# epoch 318, loss 7.663632
# epoch 319, loss 7.663632
# epoch 320, loss 7.663632
# epoch 321, loss 7.663632
# epoch 322, loss 7.663632
# epoch 323, loss 7.663632
# epoch 324, loss 7.663632
# epoch 325, loss 7.663632
# epoch 326, loss 7.663632
# epoch 327, loss 7.663632
# epoch 328, loss 7.663632
# epoch 329, loss 7.663632
# epoch 330, loss 7.663632
# epoch 331, loss 7.663632
# epoch 332, loss 7.663632
# epoch 333, loss 7.663632
# epoch 334, loss 7.663632
# epoch 335, loss 7.663632
# epoch 336, loss 7.663632
# epoch 337, loss 7.663631
# epoch 338, loss 7.663632
# epoch 339, loss 7.663631
# epoch 340, loss 7.663631
# epoch 341, loss 7.663631
# epoch 342, loss 7.663631
# epoch 343, loss 7.663631
# epoch 344, loss 7.663631
# epoch 345, loss 7.663631
# epoch 346, loss 7.663631
# epoch 347, loss 7.663632
# epoch 348, loss 7.663632
# epoch 349, loss 7.663632
# epoch 350, loss 7.663631
# epoch 351, loss 7.663631
# epoch 352, loss 7.663632
# epoch 353, loss 7.663631
# epoch 354, loss 7.663631
# epoch 355, loss 7.663631
# epoch 356, loss 7.663631
# epoch 357, loss 7.663632
# epoch 358, loss 7.663632
# epoch 359, loss 7.663632
# epoch 360, loss 7.663631
# epoch 361, loss 7.663632
# epoch 362, loss 7.663631
# epoch 363, loss 7.663631
# epoch 364, loss 7.663632
# epoch 365, loss 7.663632
# epoch 366, loss 7.663631
# epoch 367, loss 7.663631
# epoch 368, loss 7.663631
# epoch 369, loss 7.663631
# epoch 370, loss 7.663632
# epoch 371, loss 7.663631
# epoch 372, loss 7.663631
# epoch 373, loss 7.663631
# epoch 374, loss 7.663631
# epoch 375, loss 7.663631
# epoch 376, loss 7.663632
# epoch 377, loss 7.663631
# epoch 378, loss 7.663631
# epoch 379, loss 7.663631
# epoch 380, loss 7.663631
# epoch 381, loss 7.663631
# epoch 382, loss 7.663632
# epoch 383, loss 7.663632
# epoch 384, loss 7.663632
# epoch 385, loss 7.663631
# epoch 386, loss 7.663631
# epoch 387, loss 7.663631
# epoch 388, loss 7.663631
# epoch 389, loss 7.663631
# epoch 390, loss 7.663631
# epoch 391, loss 7.663632
# epoch 392, loss 7.663631
# epoch 393, loss 7.663631
# epoch 394, loss 7.663631
# epoch 395, loss 7.663632
# epoch 396, loss 7.663631
# epoch 397, loss 7.663631
# epoch 398, loss 7.663631
# epoch 399, loss 7.663631
# epoch 400, loss 7.663631

# %%
def accuracy(y_pred, y_true):
    correct_prediction = tf.equal(np.around(y_pred), tf.cast(y_true, tf.int64)) # (256,) bool
    return tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
print(accuracy(sigmoid_module(X_test, w, b), y_test))
# Out:
# tf.Tensor(0.5017869, shape=(), dtype=float32)

# %% [markdown]
# This notebook is used to make a Logistic Regression instance.
#
# First of all, import all the necessary modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# %%
Pumpkin = pd.read_excel("Pumpkin_Seeds_Dataset.xlsx")
Pumpkin.head()
# Out:
#     Area  Perimeter  Major_Axis_Length  Minor_Axis_Length  Convex_Area  \
# 0  56276    888.242           326.1485           220.2388        56831
# 1  76631   1068.146           417.1932           234.2289        77280
# 2  71623   1082.987           435.8328           211.0457        72663
# 3  66458    992.051           381.5638           222.5322        67118
# 4  66107    998.146           383.8883           220.4545        67117
#
#    Equiv_Diameter  Eccentricity  Solidity  Extent  Roundness  Aspect_Ration  \
# 0        267.6805        0.7376    0.9902  0.7453     0.8963         1.4809
# 1        312.3614        0.8275    0.9916  0.7151     0.8440         1.7811
# 2        301.9822        0.8749    0.9857  0.7400     0.7674         2.0651
# 3        290.8899        0.8123    0.9902  0.7396     0.8486         1.7146
# 4        290.1207        0.8187    0.9850  0.6752     0.8338         1.7413
#
#    Compactness       Class
# 0       0.8207  Çerçevelik
# ...

# %%
status_dict = Pumpkin["Class"].unique().tolist()

Pumpkin["Class"] = Pumpkin["Class"].apply(lambda x : status_dict.index(x))

# %%
X_train, X_test, y_train, y_test = train_test_split(Pumpkin.drop("Class", axis=1), Pumpkin["Class"], test_size=0.25)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (1875, 12) (1875,) (625, 12) (625,)

# %% [markdown]
# Thus all the data management is done, to build the model, first we need to build a linear regression classifier and the sigmoid function

# %%
def sigmoid(z):
    # this function takes the linear classifier value, to show the possibility if it's Class A or Class B
    # in other worlds, we made the linear_classifier value to 1 or 0 now, to fit two class
    # this is the activation function
    return 1 / (1 + np.exp(-z))

# %%
def propagate(w, b, X, y):
    w = grad[0]
    b = grad[1]
    
    m = X.shape[1]
    A = sigmoid(np.dot(w.T, X) + b)  
    cost = -1 / m * np.sum(Y * np.log(A) + (1 - Y) * np.log(1 - A))  
    dw = 1 / m * np.dot(X, (A - Y).T)  
    db = 1 / m * np.sum(A - Y)
    
    cost = np.squeeze(cost)

    grads = {"dw": dw,
             "db": db}
    return grads, cost

# %%
def initialize(dim):
    return [np.zeros((dim, 1)), 0]

def grad_update(w, b, d_grads, learning_rate):
    w = grad[0] - learning_rate * d_grads["dw"]
    b = grad[1] - learning_rate * d_grads['db']
    return [w,b], cost

# %%
grad = initialize(X_train.shape[1])

# %%
d_grads, cost = propagate(X_train, y_train, initialize(X_train.shape[1]))
grad, cost = grad_update(grad, d_grads, 1)
print(grad)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-222-0aba4895aef4> in <module>
# ----> 1 d_grads, cost = propagate(X_train, y_train, initialize(X_train.shape[1]))
#       2 grad, cost = grad_update(grad, d_grads, 1)
#       3 print(grad)
#
# TypeError: propagate() missing 1 required positional argument: 'y'

# %%
import tensorflow as tf

# %%
learning_rate = 0.01   #学习率
training_epochs = 25    #epoch 即完整训练数据集多少次
batch_size = 100        #batch 即每次训练用多少数据
display_step = 1        #每隔多少个epoch展示一下结果

# %% [markdown]
# # Citation
# 1. Digit Recogniser MLP Classifier for Beginners -- KEERTHANA
#
#     https://www.kaggle.com/code/thatsme123/digit-recogniser-mlp-classifier-for-beginners/notebook
#
#
# 2. Numpy硬核手写Logistic回归 -- Ma Fei
#
#     https://zhuanlan.zhihu.com/p/346717919
